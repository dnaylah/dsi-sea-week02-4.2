# %%
import scipy as sp
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import norm
# %matplotlib inline

# %%
# Generate a sequence of random variates, use the 
# random_state parameter which accepts an instance of 
# numpy.random.RandomState class, or an integer which is then used 
# to seed an internal RandomState object
# example: random = norm.rvs(size=5, random_state=1234)
random = norm.rvs(size=10000, random_state=2)
print random
# Out:
# [-0.41675785 -0.05626683 -2.1361961  ..., -0.00992378 -0.21786254
#   2.00471618]

# %%
# Use scipy.stats 'describe' to find: number of elements, min, max, 
# variance, skew, and kurtosis. Let's take a look.
n, min_max, mean, var, skew, kurt = stats.describe(random)
# Out:
#   File "<ipython-input-19-c7d19511fb42>", line 3
#     print n, min_max, mean, var, skew, kurt = stats.describe(random)
#                                             ^
# SyntaxError: invalid syntax

# %%
print stats.describe(random)
# Out:
# DescribeResult(nobs=5, minmax=(-2.136196095668454, 1.6402708084049886), mean=-0.55247710941802575, variance=2.2802328898409039, skewness=0.3883809887589884, kurtosis=-1.0862420964577628)

# %%
print("Number of elements: {0:d}".format(n))
print("Minimum: {0:8.6f} Maximum: {1:8.6f}".format(min_max[0], min_max[1]))
print("Mean: {0:8.6f}".format(mean))
print("Variance: {0:8.6f}".format(var))
print("Skew : {0:8.6f}".format(skew))
print("Kurtosis: {0:8.6f}".format(kurt))
# Out:
# Number of elements: 5
# Minimum: -2.136196 Maximum: 1.640271
# Mean: -0.552477
# Variance: 2.280233
# Skew : 0.388381
# Kurtosis: -1.086242

# %% [markdown]
# Kurtosis represents the comparison of the results to a normal distribution, and how high or low the peak will be.
#
# Skew shows whether there is a favor for right or left of the mean. the mean shifts is the graph is skewed.

# %%
plt.plot(random)

# %%
stats.norm.pdf(random, loc=0.0, scale=1.0)
# Out:
# array([ 0.36575847,  0.39831126,  0.04073753,  0.10391493,  0.07988684])

# %%
plt.hist(random)
plt.show()
